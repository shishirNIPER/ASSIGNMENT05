# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import linalg as LA


O = np.array(([0,0])) # found from eq
f = 1  # solved from equation
a=13
b=5
V1=np.array(([13,0]))
V2=np.array(([-13,0]))
F1=np.array(([5,0]))
F2=np.array(([-5,0]))


# function to generate circle
def ellipse_gen(a,b):
	len = 50
	theta = np.linspace(0,2*np.pi,len)
	x_ellipse = np.zeros((2,len))
	x_ellipse[0,:] = a*np.cos(theta)
	x_ellipse[1,:] = b*np.sin(theta)
	x_ellipse = (x_ellipse.T + O).T
	return x_ellipse
   

##Generating the circle
x_ellipse= ellipse_gen(a,b)
plt.plot(x_ellipse[0,:],x_ellipse[1,:],label='ellipse- Points $V&F$ denote vertices are focii')


#plotting and labelling of points
plt.plot(q1[0], q1[1], '.')
plt.text(q1[0] * (1 + 0.1), q1[1] * (1 + 0.1) , 'V1(13,0)')
plt.plot(q2[0], q2[1], '.')
plt.text(q2[0] * (1 -0.06), q2[1] * (1+0.05) , 'V2(-13,0)')
plt.plot(q3[0], q3[1], '.')
plt.text(q3[0] * (1 + 0.1), q3[1] * (1 - 0.1) , 'F1(5,0)')
plt.plot(q4[0], q4[1], '.')
plt.text(q4[0] * (1 + 0.1), q4[1] * (1 - 0.1) , 'F2(-5,0)')



plt.xlabel('$x$')
plt.ylabel('$y$')
plt.legend(loc='best')
plt.grid() 
plt.axis('equal')
plt.show()
